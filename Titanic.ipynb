# %%
import pandas as pd
from sklearn.metrics import accuracy_score
import numpy as np
from sklearn import tree
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv("Exercise\\titanic.csv")

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data=data.drop(['PassengerId','Name','SibSp','Ticket','Parch','Embarked','Cabin'],axis=1)
data.head(10)
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500
# 5         0       3    male   NaN   8.4583
# 6         0       1    male  54.0  51.8625
# 7         0       3    male   2.0  21.0750
# 8         1       3  female  27.0  11.1333
# 9         1       2  female  14.0  30.0708

# %%
from sklearn.preprocessing import LabelEncoder
sx=LabelEncoder()
data['Sex']=sx.fit_transform(data['Sex'])

# %%
data.head()
# Out:
#    Survived  Pclass  Sex   Age     Fare
# 0         0       3    1  22.0   7.2500
# 1         1       1    0  38.0  71.2833
# 2         1       3    0  26.0   7.9250
# 3         1       1    0  35.0  53.1000
# 4         0       3    1  35.0   8.0500

# %%
forna=data['Age'].mean()

# %%
data['Age']=data['Age'].fillna(forna)

# %%
data.head(10)
# Out:
#    Survived  Pclass  Sex        Age     Fare
# 0         0       3    1  22.000000   7.2500
# 1         1       1    0  38.000000  71.2833
# 2         1       3    0  26.000000   7.9250
# 3         1       1    0  35.000000  53.1000
# 4         0       3    1  35.000000   8.0500
# 5         0       3    1  29.699118   8.4583
# 6         0       1    1  54.000000  51.8625
# 7         0       3    1   2.000000  21.0750
# 8         1       3    0  27.000000  11.1333
# 9         1       2    0  14.000000  30.0708

# %%
X=data.drop(['Survived'],axis=1)
Y=data['Survived']

# %%
X_train, X_test, y_train, y_test=train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
model=tree.DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=model.predict(X_test)

# %%
pred=pred.reshape(-1,1)

# %%
y_test=y_test.to_numpy()
y_test=y_test.reshape(-1,1)
accuracy_score(pred,y_test)
# Out:
# 0.7988826815642458

# %%
model.score(X,Y)
# Out:
# 0.9472502805836139

# %%
model.score(X_test,y_test)
# Out:
# 0.7988826815642458

# %%
model.predict([[3,0,26.000000,7.9250]])
# Out:
# array([1], dtype=int64)
